# %% [markdown]
# # Curriculum Learning Implementation Demo
#
# This notebook demonstrates the curriculum learning implementation for image classification.
#
# **Author**: [kryptologyst](https://github.com/kryptologyst)
#
# ## ⚠️ Safety Disclaimer
#
# This is a research/educational implementation. NOT FOR PRODUCTION USE.

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

from src.data.curriculum import BasicDifficultyCurriculum
from src.models.simple_cnn import SimpleCNN
from src.utils.device import get_device, set_seed

# Set random seed for reproducibility
set_seed(42)

# Get device
device = get_device("auto")
print(f"Using device: {device}")
